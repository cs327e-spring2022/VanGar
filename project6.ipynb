# %% [markdown]
# Query One

# %%
# !mongo open_food --quiet --eval 'db.products.count()'
# Out:
# 309370

# %% [markdown]
# Query Two

# %%
# !mongo open_food --quiet --eval "db.products.find({'categories': 'Snacks, Sweet snacks, Confectioneries, Candies, Chews'}, {'product_name' : 1}).pretty()"
# Out:
# { "_id" : "0071720007105", "product_name" : "Tootsie Roll" }

# %% [markdown]
# Query Three

# %%
# %env selection = {"last_modified_t": {'$gte': 1601856000}}
# %env projection = {'code': 1, "product_name": 1}
# Out:
# env: selection={"last_modified_t": {'$gte': 1601856000}}
# env: projection={'code': 1, "product_name": 1}

# %%
# !mongo open_food --quiet --eval "db.products.find(${selection}, ${projection}).pretty()"
# Out:
# {
# 	"_id" : "0852909003299",
# 	"product_name" : "Almondmilk",
# 	"code" : "0852909003299"
# }
# {
# 	"_id" : "0840423102055",
# 	"code" : "0840423102055",
# 	"product_name" : "Garlic wine pasta with chicken meatballs with whole wheat rotini, white beans, and greens, cooked in avocado oil, and topped with parmesan and mozzarella, garlic wine pasta with chicken meatballs"
# }

# %% [markdown]
# Query Four

# %%
# !mongo open_food --quiet --eval "db.products.find({'packaging': 'Plastic'}, {}).count()"
# Out:
# 115

# %% [markdown]
# Query Five

# %%
# !mongo open_food --quiet --eval "db.products.find({'manufacturing_places': 'Austin, TX', 'stores': 'Whole Foods'}, {'code': 1, 'creator': 1, 'product_name' : 1, 'brands' : 1}).pretty()"
# Out:
# {
# 	"_id" : "0099482455859",
# 	"creator" : "usda-ndb-import",
# 	"brands" : "365 Everyday Value,Whole Foods Market  Inc.",
# 	"code" : "0099482455859",
# 	"product_name" : "Whole Wheat Bread"
# }

# %% [markdown]
# Query Six

# %%
# %env selection = {"$or": [{'brands': 'm&m\u0027s'}, {'brands' : 'mars'}, {'brands': 'Mars'}, {'brands': 'oreo'}, {'brands': 'starburst'}]}
# %env projection = {'brands': 1, 'product_name': 1}
# Out:
# env: selection={"$or": [{'brands': 'm&m\u0027s'}, {'brands' : 'mars'}, {'brands': 'Mars'}, {'brands': 'oreo'}, {'brands': 'starburst'}]}
# env: projection={'brands': 1, 'product_name': 1}

# %%
# !mongo open_food --quiet --eval "db.products.find(${selection}, ${projection}).limit(5).pretty()"
# Out:
# {
# 	"_id" : "0040000265252",
# 	"brands" : "Mars",
# 	"product_name" : "Almond & dark chocolate"
# }
# { "_id" : "0040000422068", "brands" : "mars", "product_name" : "BAR" }
# {
# 	"_id" : "0044000029524",
# 	"product_name" : "Nabisco oreo cookies double stuf 1x4.1 oz",
# 	"brands" : "oreo"
# }
# {
# 	"_id" : "0047677386518",
# 	"brands" : "m&m's",
# 	"product_name" : "M&m's, light ice cream, chocolate"
# }
# {
# 	"_id" : "04005108",
# 	"product_name" : "Real fruit juice!",
# 	"brands" : "starburst"
# }

# %% [markdown]
# Query Seven

# %%
# %env selection = {"nutriments.carbohydrates_serving": {'$gte': 18, '$lte': 25}}
# Out:
# env: selection={"nutriments.carbohydrates_serving": {'$gte': 18, '$lte': 25}}

# %%
# %env projection = {"_id": 1, "product_name": 1, "countries": 1, "ingredients_text": 1, "ingredients.rank": 1, "nutriments.carbohydrates_serving": 1}
# Out:
# env: projection={"_id": 1, "product_name": 1, "countries": 1, "ingredients_text": 1, "ingredients.rank": 1, "nutriments.carbohydrates_serving": 1}

# %%
# !mongo open_food --quiet --eval "db.products.find(${selection}, ${projection}).sort({'ingredients.rank': -1}).limit(5).pretty()"
# Out:
# {
# 	"_id" : "0686700056815",
# 	"nutriments" : {
# 		"carbohydrates_serving" : 19
# 	},
# 	"product_name" : "Gamesa Lonchera Assorted Cookies 14.3 Ounce 5 Pack Box",
# ...

# %% [markdown]
# Adding a New Doc

# %%
# %env doc = {'_id': 'sampledoc1', 'code': 'sample1', 'product_name': 'DoubleStuffedOreo', 'countries': 'United States', 'brands': 'oreo'}
# Out:
# env: doc={'_id': 'sampledoc1', 'code': 'sample1', 'product_name': 'DoubleStuffedOreo', 'countries': 'United States', 'brands': 'oreo'}

# %%
# !mongo open_food --quiet --eval "db.products.insertOne($doc)"
# Out:
# { "acknowledged" : true, "insertedId" : "sampledoc1" }

# %% [markdown]
# Updating a Field

# %%
# %env doc = "$set": {"code": "updated1"}
# Out:
# env: doc="$set": {"code": "updated1"}

# %%
# !mongo open_food --quiet --eval "db.products.update({'_id': 'sampledoc1'}, {$doc})"
# Out:
# WriteResult({ "nMatched" : 1, "nUpserted" : 0, "nModified" : 1 })

# %% [markdown]
# Selecting/Finding Updated Doc

# %%
# !mongo open_food --quiet --eval "db.products.find({'_id': 'sampledoc1'}, {}).pretty()"
# Out:
# {
# 	"_id" : "sampledoc1",
# 	"code" : "updated1",
# 	"product_name" : "DoubleStuffedOreo",
# 	"countries" : "United States",
# 	"brands" : "oreo"
# }

# %% [markdown]
# Delecting a Document

# %%
# %env selection = {'_id': 'sampledoc1'}
# Out:
# env: selection={'_id': 'sampledoc1'}

# %%
# !mongo open_food --quiet --eval "db.products.deleteOne($selection)"
# Out:
# { "acknowledged" : true, "deletedCount" : 1 }

# %% [markdown]
# Finding Deleted Document

# %%
# %env selection = {'id': 'sampledoc1'}
# Out:
# env: selection={'id': 'sampledoc1'}

# %%
# !mongo open_food --quiet --eval "db.products.findOne(${selection}, {})"
# Out:
# null
